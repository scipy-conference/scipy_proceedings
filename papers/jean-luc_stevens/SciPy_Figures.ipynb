# %%
import holoviews as hv
import numpy as np
# %output fig='png' dpi=200 size=125

# %% [markdown]
# ## Figure 1 - Elements and Containers

# %%
imdata = np.load('mandelbrot.npy')
im = hv.Image(imdata, kdims=['Re', 'Im'], label='Mandelbrot Set', bounds=(-0.25, 1.12, 0.03, 0.84))
im * hv.HLine(y=1) + im.sample(Im=1).relabel('Cross section')
# Out:
# :Layout
#    .Overlay.Mandelbrot_Set :Overlay
#       .Image.Mandelbrot_Set :Image   [Re,Im]   (z)
#       .HLine.I              :HLine   [x,y]
#    .Curve.Cross_section    :Curve   [Re]   (z)

# %% [markdown]
# ## Figure 2 - Spaces

# %%
xs = np.arange(100)
holomap = hv.HoloMap(kdims=['Frequency', 'Amplitude', 'Function'])
for freq in [0.01, 0.05, 0.1]:
    for amp in range(1,4):
        for name, fn in [('sin', np.sin), ('cos', np.cos)]:
            cdata = fn(xs*freq*np.pi)*amp
            holomap[freq, amp, name] = hv.Curve(cdata, kdims=['Phase'], vdims=['Amplitude'])
holomap + holomap.grid(['Amplitude', 'Frequency'])
# Out:
# :Layout
#    .HoloMap.I   :HoloMap   [Frequency,Amplitude,Function]
#       :Curve   [Phase]   (Amplitude)
#    .GridSpace.I :GridSpace   [Amplitude,Frequency]
#       :HoloMap   [Function]
#          :Curve   [Phase]   (Amplitude)

# %% [markdown]
# # Figure 3 - Customizing the representation

# %%
# %output fig='svg'

# %%
# %%opts Layout [aspect_weight=1 sublabel_format='{Roman}'] Image (cmap='Blues') Curve [aspect=1.25] (linewidth=3)
# im = hv.Image(imdata, kdims=['Re', 'Im'], label='Mandelbrot Set', bounds=(-0.25, 1.12, 0.03, 0.84))
# content = im * hv.HLine(y=1) + im.sample(Im=1).relabel('Cross section')
# content
# Out:
# :Layout
#    .Overlay.Mandelbrot_Set :Overlay
#       .Image.Mandelbrot_Set :Image   [Re,Im]   (z)
#       .HLine.I              :HLine   [x,y]
#    .Curve.Cross_section    :Curve   [Re]   (z)

# %%
print repr(content)
# Out:
# :Layout
#    .Overlay.Mandelbrot_Set :Overlay
#       .Image.Mandelbrot_Set :Image   [Re,Im]   (z)
#       .HLine.I              :HLine   [x,y]
#    .Curve.Cross_section    :Curve   [Re]   (z)

# %%
options = hv.Store.custom_options[content.id]
print repr(options)
# Out:
# :OptionTree
#    .Curve  :OptionTree {'plot': dict(aspect=1.25), 'style': dict(linewidth=3)}
#    .Image  :OptionTree {'style': dict(cmap='Blues')}
#    .Layout :OptionTree {'plot': dict(sublabel_format='{Roman}', aspect_weight=1)}
