# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %% [markdown]
# # Code samples in "Modeling the Earth with Fatiando a Terra" - Scipy 2013
#
# Code included in the proceedings of the 2013 Scipy conference.

# %% [markdown]
# ## Gridding and plotting

# %%
from fatiando import gridder
from fatiando.vis import mpl

area = [-50, 50, -20, 20]
x, y = gridder.scatter(area, n=100)
data = x**2 + y**2
mpl.figure()
mpl.axis('scaled')
mpl.contourf(x, y, data, shape=(50, 50), levels=30, interp=True)
mpl.colorbar(orientation='horizontal')
mpl.plot(x, y, '.k')
mpl.savefig('gridding_plotting_contourf.png')

# %%
mpl.figure()
bm = mpl.basemap(area, projection='robin')
bm.drawmapboundary()
bm.drawcoastlines()
mpl.contourf(x, y, data, shape=(50, 50), levels=30, interp=True, basemap=bm)
mpl.colorbar(orientation='horizontal')
mpl.savefig('gridding_plotting_basemap.png')

# %%
from fatiando import mesher
from fatiando.vis import myv

model = [mesher.Prism(x1=5, x2=8, y1=3, y2=7, z1=1, z2=7)]
bounds = [0, 10, 0, 10, 0, 10]
myv.figure()
myv.prisms(model)
myv.axes(myv.outline(bounds))
myv.wall_bottom(bounds)
myv.wall_north(bounds)
myv.savefig('gridding_plotting_.png')
myv.show()
