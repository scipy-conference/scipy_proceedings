# %%
import sys

# %%
sys.path.append('/home/imager/src.git/figurefirst/')

# %%
from sklearn import datasets
import figurefirst as fifi
from IPython.display import display,SVG
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sklearn import datasets
import figurefirst as fifi
from IPython.display import display,SVG
d = datasets.load_iris()
data = dict()
for n,v in zip(d.feature_names,d.data.T):
    data[tuple(n.split()[:2][::-1])] = v

layout = fifi.FigureLayout('example_layout.svg')
layout.make_mplfigures()
layout.axes['raw'].scatter(data['length','petal'],
                           data['width','petal'],
                           color = 'r')
layout.axes['raw'].scatter(data['length','sepal'],
                           data['width','sepal'],
                           color = 'b')
for key,value in data.items():
    c = {'sepal':'b','petal':'r'}[key[1]]
    layout.axes[key].plot(histogram(value)[0],c= c)
layout.apply_mpl_methods()
fifi.mpl_functions.set_spines(layout)
layout.save('example.svg')
close('all')
display(SVG('example.svg'))
