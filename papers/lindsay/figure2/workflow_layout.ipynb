# %%
# %pylab inline
from IPython.display import display, SVG
import figurefirst as fifi
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
layout = fifi.FigureLayout('workflow_layout.svg')
layout.make_mplfigures()
layout.axes.keys()

#old_way_plot = imread('old_way_plot.png')
#layout.axes['old_way_plot'].imshow(old_way_plot)
#old_way_edit = imread('old_way_edit.png')
#layout.axes['old_way_edit'].imshow(old_way_edit)
#layout.axes['old_way_start_over'].imshow(imread('old_way_start_over.png'))
draw_layout = imread('draw_layout.png')
import_layout = imread('import_layout.png')
fifi.mpl_functions.kill_all_spines(layout)
layout.axes['draw_layout'].imshow(draw_layout)
layout.axes['import_layout'].imshow(import_layout)
layout.axes['plot_data'].plot(np.linspace(0,2*pi),
                              np.sin(np.linspace(0,2*pi)))
layout.save('workflow.svg')
close('all')
display(SVG('workflow.svg'))
