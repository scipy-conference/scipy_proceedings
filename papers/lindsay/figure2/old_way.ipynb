# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
figure(figsize = (8,4.7))
ax = subplot(1,3,1)
ax.imshow(imread('old_way_plot.png'))
ax = subplot(1,3,2)
ax = subplot(1,3,3)
ax.plot(np.linspace(0,2*pi),
        np.sin(np.linspace(0,2*pi)))
savefig('old_way.svg')
